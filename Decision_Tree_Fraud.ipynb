# %% [markdown]
# Use decision trees to prepare a model on fraud data
# treating those who have taxable_income <= 30000 as "Risky" and others are "Good"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn import tree
from sklearn.tree import  DecisionTreeClassifier

# %%
data=pd.read_csv("/content/Fraud_check.csv")
data.head()
# Out:
#   Undergrad Marital.Status  ...  Work.Experience  Urban
# 0        NO         Single  ...               10    YES
# 1       YES       Divorced  ...               18    YES
# 2        NO        Married  ...               30    YES
# 3       YES         Single  ...               15    YES
# 4        NO        Married  ...               28     NO
#
# [5 rows x 6 columns]

# %%
data.describe().T
# Out:
#                  count           mean  ...        75%       max
# Taxable.Income   600.0   55208.375000  ...   78611.75   99619.0
# City.Population  600.0  108747.368333  ...  150114.25  199778.0
# Work.Experience  600.0      15.558333  ...      24.00      30.0
#
# [3 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# Undergrad          0
# Marital.Status     0
# Taxable.Income     0
# City.Population    0
# Work.Experience    0
# Urban              0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.dtypes
# Out:
# Undergrad          object
# Marital.Status     object
# Taxable.Income      int64
# City.Population     int64
# Work.Experience     int64
# Urban              object
# dtype: object

# %%
sns.boxplot(data["Taxable.Income"])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df=data.copy()

# %%
list(df.columns)
# Out:
# ['Undergrad',
#  'Marital.Status',
#  'Taxable.Income',
#  'City.Population',
#  'Work.Experience',
#  'Urban']

# %%
#df=pd.get_dummies(df,columns=['Undergrad','Marital.Status','Urban'])
df
# Out:
#      Taxable.Income  City.Population  ...  Urban_NO  Urban_YES
# 0             68833            50047  ...         0          1
# 1             33700           134075  ...         0          1
# 2             36925           160205  ...         0          1
# 3             50190           193264  ...         0          1
# 4             81002            27533  ...         1          0
# ..              ...              ...  ...       ...        ...
# 595           76340            39492  ...         0          1
# 596           69967            55369  ...         0          1
# 597           47334           154058  ...         0          1
# 598           98592           180083  ...         1          0
# 599           96519           158137  ...         1          0
#
# [600 rows x 10 columns]

# %%
df.corr()
# Out:
#                          Taxable.Income  City.Population  ...  Urban_NO  Urban_YES
# Taxable.Income                 1.000000        -0.064387  ... -0.070628   0.070628
# City.Population               -0.064387         1.000000  ...  0.040098  -0.040098
# Work.Experience               -0.001818         0.013135  ...  0.094559  -0.094559
# Undergrad_NO                   0.049232        -0.079579  ... -0.000267   0.000267
# Undergrad_YES                 -0.049232         0.079579  ...  0.000267  -0.000267
# Marital.Status_Divorced        0.062099         0.004925  ...  0.065518  -0.065518
# Marital.Status_Married        -0.100611        -0.007035  ... -0.016771   0.016771
# Marital.Status_Single          0.037910         0.002087  ... -0.047014   0.047014
# Urban_NO                      -0.070628         0.040098  ...  1.000000  -1.000000
# Urban_YES                      0.070628        -0.040098  ... -1.000000   1.000000
#
# [10 rows x 10 columns]

# %%
df["Taxable.Income"]=df["Taxable.Income"].apply(lambda x: "Risky" if x<=30000 else "Good")

# %%
df.head()
# Out:
#   Taxable.Income  City.Population  ...  Urban_NO  Urban_YES
# 0           Good            50047  ...         0          1
# 1           Good           134075  ...         0          1
# 2           Good           160205  ...         0          1
# 3           Good           193264  ...         0          1
# 4           Good            27533  ...         1          0
#
# [5 rows x 10 columns]

# %%
df["Taxable.Income"].value_counts()
# Out:
# Good     476
# Risky    124
# Name: Taxable.Income, dtype: int64

# %%
X=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
y_train.value_counts()
# Out:
# Good     374
# Risky    106
# Name: Taxable.Income, dtype: int64

# %%
DTC=DecisionTreeClassifier(criterion="entropy")

# %%
model=DTC.fit(X_train,y_train)

# %%
y_pred=model.predict(X_test)

# %%
train_pred=model.predict(X_train)

# %%
accuracy_score(y_train,train_pred)
# Out:
# 1.0

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[68, 34],
#        [14,  4]])

# %%
features=list(df.columns)
cn=list(df["Taxable.Income"].unique())

# %%
fig,axes=plt.subplots(1,1,figsize=(4,4),dpi=300)
tree.plot_tree(model,feature_names=features,class_names=cn,filled=True)
plt.show()

# %%
model.feature_importances_
# Out:
# array([0.54468489, 0.20317989, 0.03774775, 0.02953078, 0.05688327,
#        0.04948394, 0.02072324, 0.04236622, 0.01540002])

# %%
fi = pd.DataFrame({'Feature': list(X_train.columns),
                   'Importance': model.feature_importances_}).\
                    sort_values('Importance', ascending = False)
fi.head()
# Out:
#                    Feature  Importance
# 0          City.Population    0.544685
# 1          Work.Experience    0.203180
# 4  Marital.Status_Divorced    0.056883
# 5   Marital.Status_Married    0.049484
# 7                 Urban_NO    0.042366

# %% [markdown]
# ## **Conclusion:** As seen in the confusion matrix of Test data 72 instances are presdected correctly and 48 instances are not.
